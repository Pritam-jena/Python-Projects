# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_India'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, "html")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-appearance-disabled vector-feature-appearance-pinned-clientpref-0 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of largest companies in India - Wikipedia
#   </title>
#   <script>
# ...

# %%
table1 = soup.find_all('table')[0]
table1
# Out:
# <table class="wikitable sortable" style="text-align:right;">
# <tbody><tr>
# <th align="center" colspan="2">Rank
# </th>
# <th align="center" colspan="2">Forbes <br/>2000 rank
# </th>
# <th align="center">Name
# </th>
# <th align="center">Headquarters
# </th>
# <th align="center">Revenue<br/>(billions <br/>US$)
# </th>
# <th align="center">Profit<br/>(billions <br/>US$)
# </th>
# <th align="center">Assets<br/>(billions <br/>US$)
# </th>
# <th align="center">Value<br/>(billions <br/>US$)
# </th>
# <th align="center">Industry
# </th></tr>
# <tr>
# ...

# %%
world_title = table1.find_all('th')

# %%
print(world_title)
# Out:
# [<th align="center" colspan="2">Rank
# </th>, <th align="center" colspan="2">Forbes <br/>2000 rank
# </th>, <th align="center">Name
# </th>, <th align="center">Headquarters
# </th>, <th align="center">Revenue<br/>(billions <br/>US$)
# </th>, <th align="center">Profit<br/>(billions <br/>US$)
# </th>, <th align="center">Assets<br/>(billions <br/>US$)
# </th>, <th align="center">Value<br/>(billions <br/>US$)
# </th>, <th align="center">Industry
# </th>]

# %%
world_table_title = [title.text.strip() for title in world_title]

# %%
world_table_title
# Out:
# ['Rank',
#  'Forbes 2000 rank',
#  'Name',
#  'Headquarters',
#  'Revenue(billions US$)',
#  'Profit(billions US$)',
#  'Assets(billions US$)',
#  'Value(billions US$)',
#  'Industry']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=world_table_title)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Forbes 2000 rank, Name, Headquarters, Revenue(billions US$), Profit(billions US$), Assets(billions US$), Value(billions US$), Industry]
# Index: []

# %%
world_rows = table1.find_all('tr')[1:]

# %%
for rows in world_rows:
    row_data = rows.find_all('td')
    indivisual_row_data = [data.text.strip() for data in row_data]
    del indivisual_row_data[1]
    del indivisual_row_data[2]

    length = len(df)
    df.loc[length] = indivisual_row_data

# %%
df
# Out:
#    Rank Forbes 2000 rank                                Name Headquarters  \
# 0     1               54                 Reliance Industries       Mumbai
# 1     2              130                          TATA Group       Mumbai
# 2     3              105                 State Bank of India       Mumbai
# 3     4              154                           HDFC Bank       Mumbai
# 4     5              205                          ICICI Bank       Mumbai
# 5     6              229     Oil and Natural Gas Corporation    New Delhi
# 6     7              269                                HDFC       Mumbai
# 7     8              358              Indian Oil Corporation    New Delhi
# 8     9              385           Tata Consultancy Services       Mumbai
# 9    10              408                          Tata Steel       Mumbai
# 10   11              432                           Axis Bank       Mumbai
# 11   12              484                        NTPC Limited    New Delhi
# ...

# %%
df.to_csv(r"C:\Users\jenap\Desktop\Python_organised folder\Web Scarping\CompaniesRanking.csv", index = False)

# %%
table2 = soup.find_all('table')[1]

# %%
World_Title2 = table2.find_all('th')
columns_2 = [title.text.strip() for title in World_Title2]
columns_2
# Out:
# ['Rank',
#  'Name',
#  'Industry',
#  'Revenue(in  ₹ Crore)',
#  'Revenue growth',
#  'Profits(in  ₹ Crore)',
#  'Headquarters',
#  'State Controlled']

# %%
df2 = pd.DataFrame(columns=columns_2)
df2
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue(in  ₹ Crore), Revenue growth, Profits(in  ₹ Crore), Headquarters, State Controlled]
# Index: []

# %%
# Out:
# ['Rank',
#  'Name',
#  'Industry',
#  'Revenue(in  ₹ Crore)',
#  'Revenue growth',
#  'Profits(in  ₹ Crore)',
#  'Headquarters',
#  'State Controlled']

# %%
world_rows2 = table2.find_all('tr')[1:]

# %%
for rows in world_rows2:
    row_data = rows.find_all('td')
    indivisual_rowdata2 = [data.text.strip() for data in row_data]

    length = len(df2)
    df2.loc[length] = indivisual_rowdata2

# %%
df2.to_csv(r"C:\Users\jenap\Desktop\Python_organised folder\Web Scarping\2021_fortune.csv", index= False)
